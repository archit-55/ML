# %% [markdown]
# <a href="https://colab.research.google.com/github/archit-55/ML/blob/supervisedML/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://en.wikipedia.org/wiki/Cricket"

# %%
#  sending the requests to the url
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Cricket - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Cricket","wgTitle":"Cricket","wgCurRevisionId":902997048,"wgRevisionId":902997048,"wgArticleId":25675557,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Wikipedia indefinitely semi-protected pages","Use British English from May 2016","Use dmy dates from April 2019","All articles with unsourced statements","Articles with unsourced statements from September 2017","Wikipedia articles with GND identifiers","Wikipedia articles with LCCN identifiers","Wikipedia articles with NARA identifiers","Wikipedia articles with NDL identifiers","
# ...

# %%
#   parsing library  --->html parser and second is lxml
soup=BeautifulSoup(response.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Cricket - Wikipedia</title>
# ...

# %%
for Alink in soup.find_all('a'):
  #print(Alink)
 
#  for ahref in Alink
  print(Alink.get('href'))
# Out:
# None
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Cricket_(insect)
# /wiki/Cricket_(disambiguation)
# /wiki/Cricketer_(disambiguation)
# /wiki/File:Eden_Gardens_under_floodlights_during_a_match.jpg
# /wiki/Eden_Gardens
# /wiki/2016_ICC_World_Twenty20_Final
# /wiki/Sports_governing_body
# /wiki/International_Cricket_Council
# /wiki/Substitute_(cricket)
# /wiki/Mixed-sex_sports
# /wiki/Team_sport
# /wiki/Bat-and-ball_games
# /wiki/Cricket_ball
# /wiki/Cricket_Bat
# /wiki/Wicket
# /wiki/Stump_(cricket)
# /wiki/Bail_(cricket)
# /wiki/Cricket_clothing_and_equipment
# /wiki/Cricket_Field
# /wiki/Glossary_of_cricket_terms
# /wiki/Olympic_Games
# /wiki/1900_Summer_Olympics
# /wiki/Bat-and-ball_games
# /wiki/Cricket_field
# /wiki/Cricket_pitch
# /wiki/Wicket
# /wiki/Bail_(cricket)
# /wiki/Stump_(cricket)
# /wiki/Batting_(cricket)
# /wiki/Run_(cricket)
# /wiki/Cricket_ball
# /wiki/Bowling_(cricket)
# /wiki/Fielding_(cricket)
# /wiki/Dismissal_(cricket)
# ...

# %%
for ptag in soup.find_all('p'):
  print(ptag)
  #now second loop for btag
  for btag in soup.find_all('b'):
    print(btag.text)
# Out:
# <p class="mw-empty-elt">
# </p>
# Cricket
# Related sports
# ^
# ^
# ^
# a
# b
# ^
# a
# b
# c
# ^
# a
# b
# ^
# a
# b
# a
# b
# ^
# a
# b
# ^
# ^
# ^
# ^
# a
# b
# ^
# ^
# ^
# ^
# ^
# a
# b
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# a
# b
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# a
# b
# c
# d
# ^
# ^
# ^
# ^
# a
# b
# c
# d
# e
# f
# ^
# ^
# a
# b
# c
# d
# a
# b
# c
# ^
# ^
# ^
# ^
# a
# b
# a
# b
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# a
# b
# c
# d
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# a
# b
# c
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# a
# b
# c
# ^
# a
# b
# a
# b
# a
# b
# ^
# a
# b
# c
# d
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# a
# b
# c
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# ^
# Cricket
# Organisations and competitions
# Statistics and records
# News and other resources
# ...

# %%
import pandas as pd

# %%
list=[1,2,3,4]
list1=[3,4,5,5]
df=pd.DataFrame([list,list1],columns=["age","value","name","marks"])

# %%
df
# Out:
#    age  value  name  marks
# 0    1      2     3      4
# 1    3      4     5      5

# %%
n=["a",34,67]
a=["b",45,34]
m=["c",56,87]
dd=pd.DataFrame([n,a,m],columns=["name","age","marks"])

# %%
dd
# Out:
#   name  age  marks
# 0    a   34     67
# 1    b   45     34
# 2    c   56     87
