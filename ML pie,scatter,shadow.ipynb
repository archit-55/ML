# %% [markdown]
# <a href="https://colab.research.google.com/github/archit-55/ML/blob/master/ML%20pie%2Cscatter%2Cshadow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
dir(matplotlib)

# %%
del(matplotlib)

# %%
import matplotlib.pyplot as plt
# only loading python oriented libraries
x=[2,3]
x1=[4,3,8]
y=[9,5]
y1=[2,9,7]


plt.xlabel("time")
plt.ylabel("speed")
plt.plot(x,y,label="water")  #this will draw a straight line
plt.plot(x1,y1,label="sand")
plt.bar(x1,y1)         #to plot bar graphs
plt.bar(x,y)          # to plot bar graphs
plt.grid(color='green')     #to form grids in graph
plt.legend()   #to show labels with plot
plt.xlim(0,12)    # to show min and max no. in  x-axis
plt.ylim(0,15)     # to show min and max no. in  y-axis
plt.show()

# %%
import matplotlib.pyplot as plt
# only loading python oriented libraries

player=["Virat","MS Dhoni","Pandya"]
runs=[120,150,100]
plt.xlabel("player")
plt.ylabel("runs")
plt.bar(player,runs)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
import matplotlib.pyplot as plt
# only loading python oriented libraries
x=[2,3]
x1=[4,3,8]
y=[9,5]
y1=[2,9,7]


plt.xlabel("time")
plt.ylabel("speed")
#plt.plot(x,y,label="water")  #this will draw a straight line
#plt.plot(x1,y1,label="sand")
#plt.bar(x1,y1)         #to plot bar graphs
#plt.bar(x,y)          # to plot bar graphs
plt.grid(color='green')     #to form grids in graph
plt.scatter(x,y)    #to show only points
plt.scatter(x1,y1)    #to show only points
plt.legend()   #to show labels with plot
plt.xlim(0,12)    # to show min and max no. in  x-axis
plt.ylim(0,15)     # to show min and max no. in  y-axis
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
# only loading python oriented libraries

player=["Virat","MS Dhoni","Pandya","rohit"]
runs=[120,150,100,119]
exp=[0.1,0.1,0,0]

#plt.xlabel("player")
#plt.ylabel("runs")
plt.pie(runs,labels=player,explode=exp,shadow=True,autopct='%1.1f%%')   #used for pie graph
plt.legend()
plt.show()
